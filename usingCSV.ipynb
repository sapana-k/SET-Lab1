# %% [markdown]
# <a href="https://colab.research.google.com/github/sapana-k/SET-Lab/blob/main/usingCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from datetime import datetime as dt

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/hungary_chickenpox.csv')

# %%
df
# Out:
#            Date  BUDAPEST  BARANYA  BACS  BEKES  BORSOD  CSONGRAD  FEJER  \
# 0    03/01/2005       168       79    30    173     169        42    136
# 1    10/01/2005       157       60    30     92     200        53     51
# 2    17/01/2005        96       44    31     86      93        30     93
# 3    24/01/2005       163       49    43    126      46        39     52
# 4    31/01/2005       122       78    53     87     103        34     95
# ..          ...       ...      ...   ...    ...     ...       ...    ...
# 517  01/12/2014        95       12    41      6      39         0     16
# 518  08/12/2014        43       39    31     10      34         3      2
# 519  15/12/2014        35        7    15      0       0         0      7
# 520  22/12/2014        30       23     8      0      11         4      1
# 521  29/12/2014       259       42    49     32      38        15     11
#
#      GYOR  HAJDU  ...  NOGRAD  PEST  SOMOGY  SZABOLCS  TOLNA  VAS  VESZPREM  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      522 non-null    object
#  1   BUDAPEST  522 non-null    int64
#  2   BARANYA   522 non-null    int64
#  3   BACS      522 non-null    int64
#  4   BEKES     522 non-null    int64
#  5   BORSOD    522 non-null    int64
#  6   CSONGRAD  522 non-null    int64
#  7   FEJER     522 non-null    int64
#  8   GYOR      522 non-null    int64
#  9   HAJDU     522 non-null    int64
#  10  HEVES     522 non-null    int64
#  11  JASZ      522 non-null    int64
#  12  KOMAROM   522 non-null    int64
#  13  NOGRAD    522 non-null    int64
#  14  PEST      522 non-null    int64
#  15  SOMOGY    522 non-null    int64
#  16  SZABOLCS  522 non-null    int64
#  17  TOLNA     522 non-null    int64
#  18  VAS       522 non-null    int64
#  19  VESZPREM  522 non-null    int64
# ...

# %%
df['Ordinal_Date'] = pd.to_datetime(df['Date'])
df['Ordinal_Date'] = df['Ordinal_Date'].map(dt.toordinal)

# %%
df['Datetime_format'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             522 non-null    object
#  1   BUDAPEST         522 non-null    int64
#  2   BARANYA          522 non-null    int64
#  3   BACS             522 non-null    int64
#  4   BEKES            522 non-null    int64
#  5   BORSOD           522 non-null    int64
#  6   CSONGRAD         522 non-null    int64
#  7   FEJER            522 non-null    int64
#  8   GYOR             522 non-null    int64
#  9   HAJDU            522 non-null    int64
#  10  HEVES            522 non-null    int64
#  11  JASZ             522 non-null    int64
#  12  KOMAROM          522 non-null    int64
#  13  NOGRAD           522 non-null    int64
#  14  PEST             522 non-null    int64
#  15  SOMOGY           522 non-null    int64
#  16  SZABOLCS         522 non-null    int64
# ...

# %%
# %matplotlib inline
plt.scatter(df.Datetime_format, df.BUDAPEST)
plt.title('Chickenpox cases in Budapest, Hungary')
plt.xlabel('Date')
plt.ylabel('Reported cases of chickenpox')
plt.show()

# %%
df
# Out:
#            Date  BUDAPEST  BARANYA  BACS  BEKES  BORSOD  CSONGRAD  FEJER  \
# 0    03/01/2005       168       79    30    173     169        42    136
# 1    10/01/2005       157       60    30     92     200        53     51
# 2    17/01/2005        96       44    31     86      93        30     93
# 3    24/01/2005       163       49    43    126      46        39     52
# 4    31/01/2005       122       78    53     87     103        34     95
# ..          ...       ...      ...   ...    ...     ...       ...    ...
# 517  01/12/2014        95       12    41      6      39         0     16
# 518  08/12/2014        43       39    31     10      34         3      2
# 519  15/12/2014        35        7    15      0       0         0      7
# 520  22/12/2014        30       23     8      0      11         4      1
# 521  29/12/2014       259       42    49     32      38        15     11
#
#      GYOR  HAJDU  ...  NOGRAD  PEST  SOMOGY  SZABOLCS  TOLNA  VAS  VESZPREM  \
# ...

# %%
RegressionObject = linear_model.LinearRegression()
x = df[['Ordinal_Date']]
y = df.BUDAPEST
RegressionObject.fit(x, y)
date = '2008-01-01'
dtstr = dt.strptime(date, '%Y-%m-%d').date()
dtstr = pd.to_datetime(dtstr)
dtstr = dtstr.toordinal()
RegressionObject.predict([[dtstr]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([105.98222442])

# %%
date = '2014-12-22'
dtstr = dt.strptime(date, '%Y-%m-%d').date()
dtstr = pd.to_datetime(dtstr)
dtstr = dtstr.toordinal()
RegressionObject.predict([[dtstr]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([89.45684406])

# %%
print(RegressionObject.intercept_)
# Out:
# 4862.0866087175555

# %%
print(RegressionObject.coef_)
# Out:
# [-0.00648817]

# %%
# %matplotlib inline
plt.scatter(df.Datetime_format, df.BUDAPEST)
plt.title('Chickenpox cases in Budapest, Hungary')
plt.xlabel('Date')
plt.ylabel('Reported cases of chickenpox')
plt.plot(df.Datetime_format, RegressionObject.predict(df[['Ordinal_Date']]), color = 'red')
plt.show()
